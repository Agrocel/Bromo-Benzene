# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel("Z:\Bromo-Benzene-PP\Data\Raw\Bromobenzene export_data 2023- 2024.xlsx")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\MU_ICT_025\AppData\Local\Temp\ipykernel_12564\1401870251.py:1: SyntaxWarning: invalid escape sequence '\B'
#   df = pd.read_excel("Z:\Bromo-Benzene-PP\Data\Raw\Bromobenzene export_data 2023- 2024.xlsx")

# %%
import chardet

file_path = 'Z:\\Bromo-Benzene-PP\\Data\\Processed\\Bromobenzene export_data 2023- 2024.xlsx'

# Read the file as binary data
with open(file_path, 'rb') as f:
    # Read a sample of the file to guess the encoding
    result = chardet.detect(f.read(100000)) 

# The result is a dictionary with the guessed encoding
print(result)
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}

# %%
import pandas as pd 

encoding_to_try = ['utf-8', 'latin-1', 'cp1252']

df = None
for encoding1 in encoding_to_try:
    try:
        df = pd.read_excel(file_path, encoding=encoding1)
        print(f"successfully read the file{encoding1}")
        break
    except UnicodeDecodeError:
        print(f"Failed to read with encoding: {encoding}")
        continue
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        break
if df is not None:
    # Do something with your DataFrame
    print(df.head())
else:
    print("Could not read the file with any of the specified encodings.")
# Out:
# An unexpected error occurred: read_excel() got an unexpected keyword argument 'encoding'
# Could not read the file with any of the specified encodings.

# %%
df.head()
# Out:
#   IndianPort Mode of Shipment    Cush   Invoice No.  Item No.   Bill No.  \
# 0    CHENNAI              SEA  INMAA1        101868        NaN   9005024
# 1     HAZIRA              SEA  INHZA1  EXP/23-24/2         NaN   9058588
# 2    CHENNAI              SEA  INMAA1        100069        NaN   9451448
# 3    CHENNAI              SEA  INMAA1        100091        NaN   9562249
# 4  AHEMDABAD              ICD  INSBI6           NaN        NaN         0
#
#    Four Digit       Date   Hs Code  \
# 0        2903  01-Apr-23  29039990
# 1        2903  04-Apr-23  29039990
# 2        2903  21-Apr-23  29039990
# 3        2903  26-Apr-23  29039990
# 4        2903  03-May-23  29038900
#
#                                         Product Name  ...  Currency  \
# 0                                     BROMO BENZENE   ...      USD
# 1                     BROMOBENZENE (CAS # 108-86-1)   ...      USD
# 2                                     BROMO BENZENE   ...      USD
# ...
